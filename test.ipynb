# %%
import engine.core_engine as core_engine
    
x1 = core_engine.Value(1.0, label = "x1")
x2 = core_engine.Value(2.0, label = "x2")
w1 = core_engine.Value(3.0, label = "w1")
w2 = core_engine.Value(3.0, label = "w2")
b = core_engine.Value(3.0, label = "b")
x1w1 = x1 * w1
x2w2 = x2 * w2
n = x1w1 + x2w2 + b
o = n.tanh()
o.draw_graph()
